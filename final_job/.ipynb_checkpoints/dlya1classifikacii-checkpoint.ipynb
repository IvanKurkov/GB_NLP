# %%
import pandas as pd

# %%
df = pd.DataFrame({'text': ['хуй', 'Moon', 'ОРРЛПпп ваааава'], 'class': [0, 1, 2]})

# %%
df.to_csv('test.csv', index=False)

# %%
# !pip install razdel networkx pymorphy2[fast] nltk rouge==0.3.1
# !pip install --upgrade datasets tqdm transformers

# %% [markdown]
# ## Обучим модель на задачу суммаризации

# %%
from datasets import load_dataset

dataset_train = load_dataset('csv', data_files='test.csv')
# Out:
# Downloading and preparing dataset csv/default to C:/Users/user/.cache/huggingface/datasets/csv/default-8a9eebb2b9bb6cdd/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to C:/Users/user/.cache/huggingface/datasets/csv/default-8a9eebb2b9bb6cdd/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset_train
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'text', 'class'],
#         num_rows: 3
#     })
# })

# %%
dataset_test
# Out:
# Dataset({
#     features: ['url', 'title', 'text', 'topic', 'tags'],
#     num_rows: 7394
# })

# %%
dataset_test['text'][0]
# Out:
# 'Компания ООО «СГМ-Мост», занимающаяся проектированием строительством и Керченского моста, подала в арбитражный суд Ростовской области иск к турецкой Turkuaz Shipping. Об этом в среду, 13 апреля, сообщает РИА Новости. У турецкой компании планируется отсудить 35,3 миллиона рублей после того, как ее сухогруз «Лира» столкнулся с опорой строящегося моста. На данный момент иск еще не принят к производству, а основания исковых требований не сообщаются. 24 марта стало известно, что ущерб от столкновения судна с опорой моста оценивается в 120 миллионов рублей. Тогда же арбитраж по просьбе ООО «СГМ-Мост» арестовал сухогруз, оставив его в порту Таганрога. 19 марта сухогруз, шедший под флагом Панамы, протаранил опору моста №2. В результате, как писал «Крыминформ», она была разрушена, еще две получили повреждения. Пострадавших среди девяти членов экипажа «Лиры» нет. Управлял судном, направлявшимся из Черного моря в Таганрог, гражданин Турции. Источник в правоохранительных органах рассказал, что по факту столкновения возбуждено уголовное дело. Изначально сообщалось, что сухогруз принадлежит Turkuaz Shipping, однако в компании заявили, что такое судно у них не числится. Потом стало известно, что оператором «Лиры» является турецкая компания Voda Shipping, на сайте которой говорится, что владеет сухогрузом Turkuaz Shipping (зарегистрирована на Маршалловых островах). При этом, согласно информации Voda Shipping, судно ходит под флагом Белиза, а не Панамы. Поврежденный мост является вспомогательным сооружением для доставки грузов при строительстве основного сооружения — мостового перехода через Керченский пролив. Возведение временных мостов №2 и №3 должны завершить летом этого года. Первый временный мост, соединивший таманский берег с островом Тузла, открыли в октябре прошлого года. Мост через Керченский пролив длиной 19 километров станет самым протяженным в России. Он соединит Крымский полуостров с материковой частью страны автомобильной и железной дорогами. Движение автомобилей откроется в декабре 2018 года, поездов — в 2019 году.'

# %%
dataset_test['title'][0]
# Out:
# 'На владельца врезавшегося в\xa0Керченский мост сухогруза подали в\xa0суд'

# %%
model_name = "IlyaGusev/rut5_base_sum_gazeta"

# %%
def len_tok(text):
    return len(text.split())

# %%
max_len_sum, max_len_tl = max(map(len_tok, dataset_train['text'])), max(map(len_tok, dataset_train['title']))
max_len_sum, max_len_tl
# Out:
# (1243, 15)

# %%
max_len_sum, max_len_tl = 100, 15

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize(batch):
    tokenized_input = tokenizer(batch['text'], padding='max_length', truncation=True, max_length=max_len_sum)
    tokenized_label = tokenizer(batch['title'], padding='max_length', truncation=True, max_length=max_len_tl)

    tokenized_input['labels'] = tokenized_label['input_ids']

    return tokenized_input

dataset_train = dataset_train.map(tokenize, batched=True, batch_size=100)
dataset_test = dataset_test.map(tokenize, batched=True, batch_size=100)

dataset_train.set_format('numpy', columns=['input_ids', 'attention_mask', 'labels'])
dataset_test.set_format('numpy', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/36968 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7394 [00:00<?, ? examples/s]

# %%
dataset_train.save_to_disk('lenta/train')
dataset_test.save_to_disk('lenta/test')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/36968 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/7394 [00:00<?, ? examples/s]

# %%
from transformers import T5ForConditionalGeneration, Trainer, TrainingArguments


model = T5ForConditionalGeneration.from_pretrained(model_name)

# %%
output_dir = 'lenta/output'

training_args = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=10,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    eval_accumulation_steps=1, # Number of eval steps to keep in GPU (the higher, the mor vRAM used)
    prediction_loss_only=True, # If I need co compute only loss and not other metrics, setting this to true will use less RAM
    learning_rate=0.00001,
    evaluation_strategy='steps', # Run evaluation every eval_steps
    save_steps=1000, # How often to save a checkpoint
    save_total_limit=1, # Number of maximum checkpoints to save
    remove_unused_columns=True, # Removes useless columns from the dataset
    run_name='run_gazeta', # Wandb run name
    logging_steps=500, # How often to log loss to wandb
    eval_steps=500, # How often to run evaluation on the val_set
    logging_first_step=False, # Whether to log also the very first training step to wandb
    load_best_model_at_end=True, # Whether to load the best model found at each evaluation.
    metric_for_best_model="loss", # Use loss to evaluate best model.
    greater_is_better=False # Best model is the one with the lowest loss, not highest.
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset_train,
    eval_dataset=dataset_test
)

trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# C:\Users\user\anaconda3\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 36968
#   Num Epochs = 10
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 23110
#   Number of trainable parameters = 244309248
#     <div>
#
#       <progress value='23110' max='23110' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23110/23110 2:21:14, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.925200</td>
#       <td>1.981234</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.824300</td>
#       <td>1.771177</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.526800</td>
#       <td>1.665357</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.310300</td>
#       <td>1.621362</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.168300</td>
#       <td>1.574932</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.109000</td>
#       <td>1.562368</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.109000</td>
#       <td>1.554787</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.077900</td>
#       <td>1.536660</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.056400</td>
#       <td>1.528652</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.020300</td>
#       <td>1.541303</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.024200</td>
#       <td>1.507181</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.989700</td>
#       <td>1.508717</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>2.007900</td>
#       <td>1.499023</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.992100</td>
#       <td>1.503370</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.960500</td>
#       <td>1.497926</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.956900</td>
#       <td>1.491015</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.954900</td>
#       <td>1.497285</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.950800</td>
#       <td>1.475224</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.927200</td>
#       <td>1.508568</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.922100</td>
#       <td>1.489848</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.926600</td>
#       <td>1.479927</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>1.906600</td>
#       <td>1.490597</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.921600</td>
#       <td>1.496385</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.886400</td>
#       <td>1.463184</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>1.878700</td>
#       <td>1.476096</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>1.893000</td>
#       <td>1.467563</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>1.903500</td>
#       <td>1.457111</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>1.875100</td>
#       <td>1.453093</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>1.877100</td>
#       <td>1.463466</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>1.869800</td>
#       <td>1.465198</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>1.864600</td>
#       <td>1.460618</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>1.868100</td>
#       <td>1.469225</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>1.851900</td>
#       <td>1.454738</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>1.831900</td>
#       <td>1.461353</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>1.854900</td>
#       <td>1.461729</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.859600</td>
#       <td>1.455514</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>1.861800</td>
#       <td>1.454759</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.849500</td>
#       <td>1.451918</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>1.842100</td>
#       <td>1.457354</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.843000</td>
#       <td>1.454920</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>1.839700</td>
#       <td>1.469842</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.842800</td>
#       <td>1.459791</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>1.822300</td>
#       <td>1.454863</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.842900</td>
#       <td>1.453249</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>1.834900</td>
#       <td>1.453573</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>1.836300</td>
#       <td>1.455442</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-1000
# Configuration saved in lenta/output\checkpoint-1000\config.json
# Configuration saved in lenta/output\checkpoint-1000\generation_config.json
# Model weights saved in lenta/output\checkpoint-1000\pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-2000
# Configuration saved in lenta/output\checkpoint-2000\config.json
# Configuration saved in lenta/output\checkpoint-2000\generation_config.json
# Model weights saved in lenta/output\checkpoint-2000\pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-3000
# Configuration saved in lenta/output\checkpoint-3000\config.json
# Configuration saved in lenta/output\checkpoint-3000\generation_config.json
# Model weights saved in lenta/output\checkpoint-3000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-4000
# Configuration saved in lenta/output\checkpoint-4000\config.json
# Configuration saved in lenta/output\checkpoint-4000\generation_config.json
# Model weights saved in lenta/output\checkpoint-4000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-5000
# Configuration saved in lenta/output\checkpoint-5000\config.json
# Configuration saved in lenta/output\checkpoint-5000\generation_config.json
# Model weights saved in lenta/output\checkpoint-5000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-6000
# Configuration saved in lenta/output\checkpoint-6000\config.json
# Configuration saved in lenta/output\checkpoint-6000\generation_config.json
# Model weights saved in lenta/output\checkpoint-6000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-7000
# Configuration saved in lenta/output\checkpoint-7000\config.json
# Configuration saved in lenta/output\checkpoint-7000\generation_config.json
# Model weights saved in lenta/output\checkpoint-7000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-8000
# Configuration saved in lenta/output\checkpoint-8000\config.json
# Configuration saved in lenta/output\checkpoint-8000\generation_config.json
# Model weights saved in lenta/output\checkpoint-8000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-9000
# Configuration saved in lenta/output\checkpoint-9000\config.json
# Configuration saved in lenta/output\checkpoint-9000\generation_config.json
# Model weights saved in lenta/output\checkpoint-9000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-10000
# Configuration saved in lenta/output\checkpoint-10000\config.json
# Configuration saved in lenta/output\checkpoint-10000\generation_config.json
# Model weights saved in lenta/output\checkpoint-10000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-8000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-11000
# Configuration saved in lenta/output\checkpoint-11000\config.json
# Configuration saved in lenta/output\checkpoint-11000\generation_config.json
# Model weights saved in lenta/output\checkpoint-11000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-12000
# Configuration saved in lenta/output\checkpoint-12000\config.json
# Configuration saved in lenta/output\checkpoint-12000\generation_config.json
# Model weights saved in lenta/output\checkpoint-12000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-9000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-13000
# Configuration saved in lenta/output\checkpoint-13000\config.json
# Configuration saved in lenta/output\checkpoint-13000\generation_config.json
# Model weights saved in lenta/output\checkpoint-13000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-11000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-14000
# Configuration saved in lenta/output\checkpoint-14000\config.json
# Configuration saved in lenta/output\checkpoint-14000\generation_config.json
# Model weights saved in lenta/output\checkpoint-14000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-12000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-15000
# Configuration saved in lenta/output\checkpoint-15000\config.json
# Configuration saved in lenta/output\checkpoint-15000\generation_config.json
# Model weights saved in lenta/output\checkpoint-15000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-13000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-16000
# Configuration saved in lenta/output\checkpoint-16000\config.json
# Configuration saved in lenta/output\checkpoint-16000\generation_config.json
# Model weights saved in lenta/output\checkpoint-16000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-15000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-17000
# Configuration saved in lenta/output\checkpoint-17000\config.json
# Configuration saved in lenta/output\checkpoint-17000\generation_config.json
# Model weights saved in lenta/output\checkpoint-17000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-16000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-18000
# Configuration saved in lenta/output\checkpoint-18000\config.json
# Configuration saved in lenta/output\checkpoint-18000\generation_config.json
# Model weights saved in lenta/output\checkpoint-18000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-17000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-19000
# Configuration saved in lenta/output\checkpoint-19000\config.json
# Configuration saved in lenta/output\checkpoint-19000\generation_config.json
# Model weights saved in lenta/output\checkpoint-19000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-14000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-20000
# Configuration saved in lenta/output\checkpoint-20000\config.json
# Configuration saved in lenta/output\checkpoint-20000\generation_config.json
# Model weights saved in lenta/output\checkpoint-20000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-18000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-21000
# Configuration saved in lenta/output\checkpoint-21000\config.json
# Configuration saved in lenta/output\checkpoint-21000\generation_config.json
# Model weights saved in lenta/output\checkpoint-21000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-20000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-22000
# Configuration saved in lenta/output\checkpoint-22000\config.json
# Configuration saved in lenta/output\checkpoint-22000\generation_config.json
# Model weights saved in lenta/output\checkpoint-22000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-21000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: title, url, tags, text, topic. If title, url, tags, text, topic are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 7394
#   Batch size = 16
# Saving model checkpoint to lenta/output\checkpoint-23000
# Configuration saved in lenta/output\checkpoint-23000\config.json
# Configuration saved in lenta/output\checkpoint-23000\generation_config.json
# Model weights saved in lenta/output\checkpoint-23000\pytorch_model.bin
# Deleting older checkpoint [lenta\output\checkpoint-22000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from lenta/output\checkpoint-19000 (score: 1.4519178867340088).
# Deleting older checkpoint [lenta\output\checkpoint-19000] due to args.save_total_limit
# Deleting older checkpoint [lenta\output\checkpoint-23000] due to args.save_total_limit
# TrainOutput(global_step=23110, training_loss=2.005596460320123, metrics={'train_runtime': 8475.8997, 'train_samples_per_second': 43.615, 'train_steps_per_second': 2.727, 'total_flos': 4.907911901184e+16, 'train_loss': 2.005596460320123, 'epoch': 10.0})

# %%
trainer.save_model(output_dir + '/model')
# Out:
# Saving model checkpoint to lenta/output/model
# Configuration saved in lenta/output/model\config.json
# Configuration saved in lenta/output/model\generation_config.json
# Model weights saved in lenta/output/model\pytorch_model.bin

# %%
INX = 100
print("SUMMARY: | {}".format(dataset_test['text'][INX]))
print("TITLE: | {}".format(dataset_test['title'][INX]))
# Out:
# SUMMARY: | Мик Шумахер, сын немецкого гонщика Михаэля Шумахера, в ближайшее время не собирается выступать в «Формуле-1». Об этом в среду, 13 апреля, сообщила менеджер знаменитого гонщика Сабина Кем. Ее слова приводит Corriere dello Sport. «За последний год Мик стал намного опытнее. У него произошли изменения в личной жизни. Он стал сильнее психологически, но до перехода в "Формулу-1" еще далеко. Пока мы об этом даже не думаем. Ему будет полезно провести еще один сезон в "Формуле-4", где он блестяще дебютировал. Мы за него очень рады», — сказала Кем. Мик Шумахер в нынешнем сезоне выступает в итальянской серии «Формулы-4». В прошлом году, который стал для 17-летнего немца дебютным, он занял 10-е место в личном зачете чемпионата, выиграв одну гонку. Шумахер-старший в настоящее время проходит курс реабилитации на собственной вилле на берегу Женевского озера в Швейцарии. Он вернулся туда из клиники в сентябре 2014 года. До этого Шумахер более полугода находился в коме из-за несчастного случая, произошедшего во время катания на горных лыжах в декабре 2013 года. Тогда немец упал и ударился головой о камень. О состоянии здоровья 47-летнего спортсмена известно лишь, что он уже не прикован к постели и может, например, сидеть в кресле. Шумахер узнает родственников, но не говорит, так как мышцы его лица атрофировались.
# TITLE: | Менеджер оценила перспективы сына Шумахера в «Формуле-1»

# %%
device = "cuda"

# %%
import torch

input_text = dataset_test['text'][INX]

with torch.no_grad():
    tokenized_text = tokenizer(input_text, truncation=True, padding=True, return_tensors='pt')

    source_ids = tokenized_text['input_ids'].to(device, dtype = torch.long)
    source_mask = tokenized_text['attention_mask'].to(device, dtype = torch.long)

    generated_ids = model.generate(
        input_ids = source_ids,
        attention_mask = source_mask, 
        max_length=512,
        num_beams=7,
        temperature = 1.3,
        repetition_penalty=1, 
        length_penalty=1, 
        early_stopping=True,
        no_repeat_ngram_size=2
    )

    pred = tokenizer.decode(generated_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)

print("\noutput:\n" + pred)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Generate config GenerationConfig {
#   "bos_token_id": 2,
#   "decoder_start_token_id": 2,
#   "eos_token_id": 1,
#   "max_length": 200,
#   "num_beams": 5,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
# output:
# В «Формуле-1» появился сын Шумахера
